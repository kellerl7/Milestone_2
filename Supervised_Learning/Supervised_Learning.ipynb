# %%
import pandas as pd

# Define years and file pattern
years = range(2009, 2023)
file_pattern = "../Data/{}_census_data.csv"

# List to store processed DataFrames
df_list = []

for year in years:
    file_name = file_pattern.format(year)

    try:
        # Read CSV file
        census_data = pd.read_csv(file_name)

        # Remove 'County' from county_name
        census_data['county_name'] = census_data['county_name'].str.rsplit(' ', n=1).str[0]

        # Save modified file back
        census_data.to_csv(file_name, index=False)
        print(f"Changes saved to: {file_name}")

        # Add 'Year' column and store in list
        census_data['Year'] = year
        df_list.append(census_data)

    except FileNotFoundError:
        print(f"Warning: Could not find {file_name}")
    except Exception as e:
        print(f"Error processing {file_name}: {str(e)}")
# Out:
# Changes saved to: ../Data/2009_census_data.csv
# Changes saved to: ../Data/2010_census_data.csv
# Changes saved to: ../Data/2011_census_data.csv
# Changes saved to: ../Data/2012_census_data.csv
# Changes saved to: ../Data/2013_census_data.csv
# Changes saved to: ../Data/2014_census_data.csv
# Changes saved to: ../Data/2015_census_data.csv
# Changes saved to: ../Data/2016_census_data.csv
# Changes saved to: ../Data/2017_census_data.csv
# Changes saved to: ../Data/2018_census_data.csv
# Changes saved to: ../Data/2019_census_data.csv
# Changes saved to: ../Data/2020_census_data.csv
# Changes saved to: ../Data/2021_census_data.csv
# Changes saved to: ../Data/2022_census_data.csv

# %%
#Data preprocessing ensuring no - or NaN values
for i, df in enumerate(df_list):
    old = len(df)

    df = df[(df["unemployment %"] != "(X)") & (df["% below poverty line"] != "(X)")]
    df = df[df['median house value']>=0]
    df = df[df['median income']>=0]
    df = df.dropna()

    df_list[i] = df
    
    new = len(df)

    print('\n')
    print(df.min())
    print(df.max())
    if new == 0:
        print('all data dropped')
    else:
        print('rows reduced by: ', 1-new/old)
# Out:
# mil pop                 NaN
# unemployment %          NaN
# mean income             NaN
# median income           NaN
# vacant housing units    NaN
# rental vacany rate      NaN
# % below poverty line    NaN
# median house value      NaN
# NAME                    NaN
# state                   NaN
# county                  NaN
# county_name             NaN
# state_name              NaN
# Year                    NaN
# dtype: object
# mil pop                 NaN
# unemployment %          NaN
# mean income             NaN
# median income           NaN
# vacant housing units    NaN
# rental vacany rate      NaN
# % below poverty line    NaN
# median house value      NaN
# NAME                    NaN
# state                   NaN
# county                  NaN
# county_name             NaN
# state_name              NaN
# Year                    NaN
# dtype: object
# all data dropped
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      15294.0
# median income                                    10932.0
# vacant housing units                                42.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               18600.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2010
# dtype: object
# mil pop                                      77935.0
# unemployment %                                  33.6
# mean income                                 137811.0
# median income                               115574.0
# vacant housing units                        236952.0
# rental vacany rate                              64.9
# % below poverty line                            61.2
# median house value                         1000001.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2010
# dtype: object
# rows reduced by:  0.0003104625892580426
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      16496.0
# median income                                    11391.0
# vacant housing units                                44.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               16800.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2011
# dtype: object
# mil pop                                      77516.0
# unemployment %                                  33.5
# mean income                                 141969.0
# median income                               120332.0
# vacant housing units                        242747.0
# rental vacany rate                              68.0
# % below poverty line                            62.1
# median house value                          993900.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2011
# dtype: object
# rows reduced by:  0.0003104625892580426
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      16495.0
# median income                                    12094.0
# vacant housing units                                35.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               19400.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2012
# dtype: object
# mil pop                                      79603.0
# unemployment %                                  33.0
# mean income                                 144429.0
# median income                               122844.0
# vacant housing units                        245069.0
# rental vacany rate                              66.9
# % below poverty line                            59.5
# median house value                          944100.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2012
# dtype: object
# rows reduced by:  0.0003104625892580426
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      17727.0
# median income                                    11528.0
# vacant housing units                                30.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               19900.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2013
# dtype: object
# mil pop                                      79620.0
# unemployment %                                  33.7
# mean income                                 146599.0
# median income                               122238.0
# vacant housing units                        242931.0
# rental vacany rate                              66.1
# % below poverty line                            59.5
# median house value                          929700.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2013
# dtype: object
# rows reduced by:  0.0003104625892580426
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      17517.0
# median income                                    10550.0
# vacant housing units                                31.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               20000.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2014
# dtype: object
# mil pop                                      75910.0
# unemployment %                                  34.0
# mean income                                 152424.0
# median income                               123966.0
# vacant housing units                        239973.0
# rental vacany rate                              61.5
# % below poverty line                            62.0
# median house value                          912600.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2014
# dtype: object
# rows reduced by:  0.00031055900621113075
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      15796.0
# median income                                    10499.0
# vacant housing units                                46.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               20400.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2015
# dtype: object
# mil pop                                      75665.0
# unemployment %                                  36.5
# mean income                                 164844.0
# median income                               123453.0
# vacant housing units                        233590.0
# rental vacany rate                              53.6
# % below poverty line                            60.2
# median house value                          902500.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2015
# dtype: object
# rows reduced by:  0.0009316770186335033
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      15734.0
# median income                                    11296.0
# vacant housing units                                45.0
# rental vacany rate                                   0.0
# % below poverty line                                 1.1
# median house value                               19800.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2016
# dtype: object
# mil pop                                      74543.0
# unemployment %                                  36.0
# mean income                                 164508.0
# median income                               125672.0
# vacant housing units                        225736.0
# rental vacany rate                              48.6
# % below poverty line                            61.2
# median house value                          966600.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2016
# dtype: object
# rows reduced by:  0.0009316770186335033
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      16697.0
# median income                                    11680.0
# vacant housing units                                43.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               18700.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2017
# dtype: object
# mil pop                                      72524.0
# unemployment %                                  40.9
# mean income                                 166856.0
# median income                               129588.0
# vacant housing units                        227426.0
# rental vacany rate                              57.5
# % below poverty line                            62.8
# median house value                          995900.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2017
# dtype: object
# rows reduced by:  0.0006211180124223725
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      16537.0
# median income                                    12812.0
# vacant housing units                                44.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               20700.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2018
# dtype: object
# mil pop                                      73294.0
# unemployment %                                  38.4
# mean income                                 181724.0
# median income                               136268.0
# vacant housing units                        225324.0
# rental vacany rate                              59.7
# % below poverty line                            60.8
# median house value                         1056500.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2018
# dtype: object
# rows reduced by:  0.0009316770186335033
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      16881.0
# median income                                    12441.0
# vacant housing units                                47.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               24400.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2019
# dtype: object
# mil pop                                      74498.0
# unemployment %                                  34.1
# mean income                                 181261.0
# median income                               142299.0
# vacant housing units                        226005.0
# rental vacany rate                              58.9
# % below poverty line                            59.9
# median house value                         1097800.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2019
# dtype: object
# rows reduced by:  0.0006211180124223725
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      16914.0
# median income                                    12283.0
# vacant housing units                                52.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               22800.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2020
# dtype: object
# mil pop                                      78491.0
# unemployment %                                  34.8
# mean income                                 183898.0
# median income                               147111.0
# vacant housing units                        227286.0
# rental vacany rate                              70.6
# % below poverty line                            61.4
# median house value                         1163100.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2020
# dtype: object
# rows reduced by:  0.0018627755355479225
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      18298.0
# median income                                    12856.0
# vacant housing units                                53.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               22600.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2021
# dtype: object
# mil pop                                      83038.0
# unemployment %                                  34.1
# mean income                                 196442.0
# median income                               156821.0
# vacant housing units                        235990.0
# rental vacany rate                              65.1
# % below poverty line                            64.0
# median house value                         1225900.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2021
# dtype: object
# rows reduced by:  0.0009313877677740168
#
#
# mil pop                                              0.0
# unemployment %                                       0.0
# mean income                                      20569.0
# median income                                    14525.0
# vacant housing units                                47.0
# rental vacany rate                                   0.0
# % below poverty line                                 0.0
# median house value                               40500.0
# NAME                    Abbeville County, South Carolina
# state                                                  1
# county                                                 1
# county_name                                    Abbeville
# state_name                                       Alabama
# Year                                                2022
# dtype: object
# mil pop                                      86010.0
# unemployment %                                  32.0
# mean income                                 216684.0
# median income                               170463.0
# vacant housing units                        236468.0
# rental vacany rate                              65.5
# % below poverty line                            62.5
# median house value                         1441300.0
# NAME                    Ziebach County, South Dakota
# state                                             72
# county                                           840
# county_name                                  Ziebach
# state_name                                   Wyoming
# Year                                            2022
# dtype: object
# rows reduced by:  0.0012414649286157653

# %%
#Combine all years dataframes into one
df_full = pd.concat(df_list)
# Out:
# /var/folders/l3/_1k9wdns31b0ldkbk1v_1nwm0000gn/T/ipykernel_2493/2619052009.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_full = pd.concat(df_list)

# %%
#Drop any counties that do not exist for every year of data
df_filter = df_full[df_full.groupby('NAME')['NAME'].transform('size').gt(12)]

# %%
#Group counties together by using a multiindex
df_filter = df_filter.set_index(['NAME', 'Year'])
df_filter = df_filter.sort_index(level=0)

# %%
df_filter[['unemployment %', '% below poverty line', 'rental vacany rate']] = df_filter[['unemployment %', '% below poverty line', 'rental vacany rate']]/100

# %%
df_filter['change in mil'] = df_filter['mil pop'].diff(1)
df_filter['change in mil'] = df_filter.groupby(level = 0)['change in mil'].shift(-1)

# %%
X = df_filter.reset_index()
X = X.loc[:, [*X.columns[0:10], 'change in mil']].dropna()
X = X.sort_values(by=['Year','NAME'])
display(X)
# Out:
#                                    NAME  Year  mil pop  unemployment %  \
# 0      Abbeville County, South Carolina  2010     13.0           0.144
# 13             Acadia Parish, Louisiana  2010     33.0           0.067
# 26            Accomack County, Virginia  2010     37.0           0.092
# 39                    Ada County, Idaho  2010   1204.0           0.066
# 52                   Adair County, Iowa  2010      0.0           0.045
# ...                                 ...   ...      ...             ...
# 41533              Yuma County, Arizona  2021   4001.0           0.084
# 41546             Yuma County, Colorado  2021      0.0           0.060
# 41559              Zapata County, Texas  2021      0.0           0.083
# 41572              Zavala County, Texas  2021     13.0           0.037
# 41585      Ziebach County, South Dakota  2021      0.0           0.324
#
#        mean income  median income  vacant housing units  rental vacany rate  \
# 0          41816.0        33143.0                2201.0               0.059
# 13         48844.0        37261.0                3080.0               0.078
# 26         53240.0        41372.0                6843.0               0.036
# 39         72123.0        55835.0               10170.0               0.062
# 52         53911.0        45202.0                 358.0               0.043
# ...            ...            ...                   ...                 ...
# 41533      68613.0        52563.0               18974.0               0.059
# 41546      74972.0        56327.0                 427.0               0.009
# 41559      60557.0        34406.0                1781.0               0.043
# 41572      54300.0        44573.0                 574.0               0.060
# 41585      66610.0        38750.0                 213.0               0.088
#
#        % below poverty line  median house value  change in mil
# 0                     0.163             85900.0            8.0
# 13                    0.172             86700.0          -20.0
# 26                    0.097            149800.0           27.0
# 39                    0.069            214500.0         -214.0
# 52                    0.057             93800.0            0.0
# ...                     ...                 ...            ...
# 41533                 0.154            148900.0          -79.0
# 41546                 0.104            184400.0            0.0
# 41559                 0.276             82800.0            0.0
# 41572                 0.206             63300.0            6.0
# 41585                 0.341             78000.0            0.0
#
# [38388 rows x 11 columns]

# %%
y = df_filter.groupby(level = 0).shift(-1).reset_index()
y = y.loc[:, ['NAME', 'Year',*X.columns[3:10]]].dropna()
y = y.sort_values(by=['Year','NAME'])
display(y)
y = y.loc[:, [*X.columns[3:10]]]
# Out:
#                                    NAME  Year  unemployment %  mean income  \
# 0      Abbeville County, South Carolina  2010           0.142      43780.0
# 13             Acadia Parish, Louisiana  2010           0.083      51108.0
# 26            Accomack County, Virginia  2010           0.076      55531.0
# 39                    Ada County, Idaho  2010           0.078      72128.0
# 52                   Adair County, Iowa  2010           0.044      55100.0
# ...                                 ...   ...             ...          ...
# 41533              Yuma County, Arizona  2021           0.083      74377.0
# 41546             Yuma County, Colorado  2021           0.057      81329.0
# 41559              Zapata County, Texas  2021           0.081      56419.0
# 41572              Zavala County, Texas  2021           0.058      60004.0
# 41585      Ziebach County, South Dakota  2021           0.320      78898.0
#
#        median income  vacant housing units  rental vacany rate  \
# 0            34670.0                2271.0               0.050
# 13           37970.0                3178.0               0.087
# 26           41595.0                7208.0               0.043
# 39           55304.0               10328.0               0.057
# 52           47623.0                 450.0               0.059
# ...              ...                   ...                 ...
# 41533        56439.0               18130.0               0.058
# 41546        60118.0                 360.0               0.005
# 41559        35061.0                1603.0               0.016
# 41572        49243.0                 529.0               0.048
# 41585        46023.0                 212.0               0.097
#
#        % below poverty line  median house value
# 0                     0.149             89100.0
# 13                    0.169             90900.0
# 26                    0.105            153400.0
# 39                    0.077            206200.0
# 52                    0.069             93300.0
# ...                     ...                 ...
# 41533                 0.148            173500.0
# 41546                 0.107            201500.0
# 41559                 0.315             84800.0
# 41572                 0.210             77300.0
# 41585                 0.331             93000.0
#
# [38388 rows x 9 columns]

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(5)

all_splits = list(tscv.split(X, y))
train_0, test_0 = all_splits[0]

# %%
#Chekc to ensure all counties have 2 entries in first split
X.iloc[test_0].groupby('NAME').count().Year.unique()
# Out:
# array([2])

# %%
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

mae_list = []

n_features = ['mean income', 'median income', 'vacant housing units', 'median house value', 'mil pop', 'change in mil']
n_pipeline = Pipeline([
    ('scaler', MinMaxScaler())
])

c_features = ['NAME']
c_pipeline = Pipeline([
    ('encoder',  OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers = [
        ("num", n_pipeline, n_features),
        ("cat", c_pipeline, c_features),
    ]
)

model = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

for train_index, test_index in all_splits:
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    mae = mean_absolute_percentage_error(y_test, y_pred, multioutput = 'raw_values')
    mae_list.append(mae)

pd.DataFrame(mae_list, columns = y.columns)
# Out:
#    unemployment %  mean income  median income  vacant housing units  \
# 0    2.985859e+10     0.033342       0.035455              0.075086
# 1    8.155509e+10     0.031400       0.033204              0.090011
# 2    4.053916e+11     0.044462       0.045190              0.109276
# 3    4.076329e+11     0.033224       0.037342              0.127716
# 4    4.624115e+11     0.050201       0.052224              0.136592
#
#    rental vacany rate  % below poverty line  median house value
# 0        2.207949e+12          4.824460e+09            0.033155
# 1        2.775567e+12          3.867728e+10            0.035333
# 2        3.826272e+12          8.966879e+10            0.041622
# 3        6.004314e+12          1.624985e+11            0.044161
# 4        8.381150e+12          1.705476e+11            0.060192

# %%
pd.DataFrame(model.predict(X_test), columns = y.columns)
# Out:
#       unemployment %   mean income  median income  vacant housing units  \
# 0           0.071169  63769.029821   45243.548798           2460.301321
# 1           0.076753  64651.335090   45781.596623           4056.450333
# 2           0.044147  64663.563942   47106.544053           7701.500814
# 3           0.031535  97221.467309   72750.225064           7377.681281
# 4           0.022750  69056.222940   56369.839878            465.463090
# ...              ...           ...            ...                   ...
# 6393        0.088902  70118.402901   53497.761852          19083.502796
# 6394       -0.001484  77096.252151   58224.385718            379.757995
# 6395        0.079761  61858.360184   36848.688964           1741.473499
# 6396        0.059097  56930.358613   45050.968874            376.366404
# 6397        0.227850  68170.392408   43069.646027            -52.497210
#
#       rental vacany rate  % below poverty line  median house value
# 0               0.014221              0.140730       110978.170475
# 1               0.077448              0.161358       135775.086659
# 2               0.033043              0.116186       179048.835112
# 3               0.036718              0.055281       310150.618023
# 4               0.088160              0.043228       116398.305343
# ...                  ...                   ...                 ...
# 6393            0.080142              0.152165       154335.386614
# 6394            0.045406              0.058987       198615.091875
# 6395            0.092448              0.281499        91126.617366
# 6396            0.055981              0.253451        76499.185776
# 6397            0.035333              0.349078        90955.258929
#
# [6398 rows x 7 columns]

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

mae_list = []

n_features = ['mean income', 'median income', 'vacant housing units', 'median house value', 'mil pop', 'change in mil']
n_pipeline = Pipeline([
    ('scaler', MinMaxScaler())
])

c_features = ['NAME']
c_pipeline = Pipeline([
    ('encoder',  OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers = [
        ("num", n_pipeline, n_features),
        ("cat", c_pipeline, c_features),
    ]
)

model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', RandomForestRegressor(verbose = True))
])

for train_index, test_index in all_splits:
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    mae = mean_absolute_percentage_error(y_test, y_pred, multioutput = 'raw_values')
    mae_list.append(mae)

pd.DataFrame(mae_list, columns = y.columns)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.4s
#    unemployment %  mean income  median income  vacant housing units  \
# 0    1.073670e+11     0.030016       0.034310              0.485301
# 1    2.515835e+11     0.029905       0.032409              0.442693
# 2    7.146561e+11     0.037652       0.037025              0.435211
# 3    8.783357e+11     0.034133       0.039825              0.464786
# 4    8.631383e+11     0.054945       0.053309              0.572720
#
#    rental vacany rate  % below poverty line  median house value
# 0        5.915905e+12          3.639201e+10            0.031349
# 1        4.512793e+12          1.331089e+10            0.032352
# 2        5.153060e+12          1.816363e+11            0.037764
# 3        7.747888e+12          2.671751e+11            0.040900
# 4        1.065038e+13          1.871197e+11            0.070540

# %%
display(pd.DataFrame(model.predict(X_test), columns = y.columns).min())
display(pd.DataFrame(model.predict(X_test), columns = y.columns).max())
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# unemployment %              0.01417
# mean income             19215.02000
# median income           13639.64000
# vacant housing units      192.18000
# rental vacany rate          0.02168
# % below poverty line        0.02544
# median house value      27944.00000
# dtype: float64
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# unemployment %          2.690800e-01
# mean income             1.737350e+05
# median income           1.321849e+05
# vacant housing units    2.044672e+05
# rental vacany rate      2.338200e-01
# % below poverty line    5.674100e-01
# median house value      1.136943e+06
# dtype: float64

# %%
y = df_filter.groupby(level = 0).shift(-1).reset_index()
y = y.loc[:, ['NAME', 'Year','mean income', 'median income', 'median house value']].dropna()
y = y.sort_values(by=['Year','NAME'])
display(y)
y = y.loc[:, ['mean income', 'median income', 'median house value']]
# Out:
#                                    NAME  Year  mean income  median income  \
# 0      Abbeville County, South Carolina  2010      43780.0        34670.0
# 13             Acadia Parish, Louisiana  2010      51108.0        37970.0
# 26            Accomack County, Virginia  2010      55531.0        41595.0
# 39                    Ada County, Idaho  2010      72128.0        55304.0
# 52                   Adair County, Iowa  2010      55100.0        47623.0
# ...                                 ...   ...          ...            ...
# 41533              Yuma County, Arizona  2021      74377.0        56439.0
# 41546             Yuma County, Colorado  2021      81329.0        60118.0
# 41559              Zapata County, Texas  2021      56419.0        35061.0
# 41572              Zavala County, Texas  2021      60004.0        49243.0
# 41585      Ziebach County, South Dakota  2021      78898.0        46023.0
#
#        median house value
# 0                 89100.0
# 13                90900.0
# 26               153400.0
# 39               206200.0
# 52                93300.0
# ...                   ...
# 41533            173500.0
# 41546            201500.0
# 41559             84800.0
# 41572             77300.0
# 41585             93000.0
#
# [38388 rows x 5 columns]

# %%
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

mae_list = []

n_features = ['mean income', 'median income', 'vacant housing units', 'median house value', 'mil pop', 'change in mil']
n_pipeline = Pipeline([
    ('scaler', MinMaxScaler())
])

c_features = ['NAME']
c_pipeline = Pipeline([
    ('encoder',  OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers = [
        ("num", n_pipeline, n_features),
        ("cat", c_pipeline, c_features),
    ]
)

model_linear = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

for train_index, test_index in all_splits:
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model_linear.fit(X_train, y_train)
    y_pred = model_linear.predict(X_test)
    
    mae = mean_absolute_percentage_error(y_test, y_pred, multioutput = 'raw_values')
    mae_list.append(mae)

mae_linear = pd.DataFrame(mae_list, columns = y.columns)
mae_linear
# Out:
#    mean income  median income  median house value
# 0     0.033342       0.035455            0.033155
# 1     0.031400       0.033204            0.035333
# 2     0.044462       0.045190            0.041622
# 3     0.033224       0.037342            0.044161
# 4     0.050201       0.052224            0.060192

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

mae_list = []

n_features = ['mean income', 'median income', 'vacant housing units', 'median house value', 'mil pop', 'change in mil']
n_pipeline = Pipeline([
    ('scaler', MinMaxScaler())
])

c_features = ['NAME']
c_pipeline = Pipeline([
    ('encoder',  OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers = [
        ("num", n_pipeline, n_features),
        ("cat", c_pipeline, c_features),
    ]
)

model_forest = Pipeline([
    ('preprocessor', preprocessor),
    ('model', RandomForestRegressor(verbose = True))
])

for train_index, test_index in all_splits:
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model_forest.fit(X_train, y_train)
    y_pred = model_forest.predict(X_test)
    
    mae = mean_absolute_percentage_error(y_test, y_pred, multioutput = 'raw_values')
    mae_list.append(mae)

mae_forest = pd.DataFrame(mae_list, columns = y.columns)
mae_forest
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.2s

# %%
mae_forest.mean()
# Out:
# mean income           0.036104
# median income         0.038280
# median house value    0.042554
# dtype: float64

# %%
mae_linear.mean()
# Out:
# mean income           0.038526
# median income         0.040683
# median house value    0.042893
# dtype: float64

# %%
from sklearn.model_selection import cross_validate
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

mae_list = []

n_features = ['mean income', 'median income', 'vacant housing units', 'median house value', 'mil pop', 'change in mil']
n_pipeline = Pipeline([
    ('scaler', MinMaxScaler())
])

c_features = ['NAME']
c_pipeline = Pipeline([
    ('encoder',  OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers = [
        ("num", n_pipeline, n_features),
        ("cat", c_pipeline, c_features),
    ]
)

model_NN = Pipeline([
    ('preprocessor', preprocessor),
    ('model', MLPRegressor(verbose = True))
])

for train_index, test_index in all_splits:
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model_NN.fit(X_train, y_train)
    y_pred = model_forest.predict(X_test)
    
    mae = mean_absolute_percentage_error(y_test, y_pred, multioutput = 'raw_values')
    mae_list.append(mae)

mae_NN = pd.DataFrame(mae_list, columns = y.columns)
mae_NN
# Out:
# Iteration 1, loss = 4952576988.88075829
# Iteration 2, loss = 4952522232.05840874
# Iteration 3, loss = 4952418640.80808926
# Iteration 4, loss = 4952258770.81443787
# Iteration 5, loss = 4952036945.98450279
# Iteration 6, loss = 4951751404.30079365
# Iteration 7, loss = 4951399160.95083618
# Iteration 8, loss = 4950977315.84046268
# Iteration 9, loss = 4950480457.49707222
# Iteration 10, loss = 4949909551.53738976
# Iteration 11, loss = 4949265064.71854401
# Iteration 12, loss = 4948550227.83151627
# Iteration 13, loss = 4947769297.12945175
# Iteration 14, loss = 4946920663.51515484
# Iteration 15, loss = 4946008891.17806721
# Iteration 16, loss = 4945034302.03838062
# Iteration 17, loss = 4943997039.12733936
# Iteration 18, loss = 4942891010.98555374
# Iteration 19, loss = 4941710637.26155472
# Iteration 20, loss = 4940461336.58902168
# Iteration 21, loss = 4939153716.55593586
# Iteration 22, loss = 4937781025.99345970
# Iteration 23, loss = 4936350963.69846916
# Iteration 24, loss = 4934862925.53289223
# Iteration 25, loss = 4933312520.07817554
# Iteration 26, loss = 4931711196.71338177
# Iteration 27, loss = 4930049465.02128983
# Iteration 28, loss = 4928337929.20246792
# Iteration 29, loss = 4926563842.89579582
# Iteration 30, loss = 4924740589.61573124
# Iteration 31, loss = 4922865191.31756115
# Iteration 32, loss = 4920936031.34428406
# Iteration 33, loss = 4918951700.44782639
# Iteration 34, loss = 4916921685.70870209
# Iteration 35, loss = 4914833403.96246052
# Iteration 36, loss = 4912685249.56974411
# Iteration 37, loss = 4910488820.58553410
# Iteration 38, loss = 4908225323.28397655
# Iteration 39, loss = 4905923926.46206474
# Iteration 40, loss = 4903564310.38054180
# Iteration 41, loss = 4901161748.21846485
# Iteration 42, loss = 4898706979.80590343
